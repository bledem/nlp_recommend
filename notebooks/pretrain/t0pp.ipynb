# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("bigscience/T0_3B")
model = AutoModelForSeq2SeqLM.from_pretrained("bigscience/T0_3B")

test_sentence = "Is this review positive or negative? Review: this is the best cast iron skillet you will ever buy"
inputs = tokenizer.encode("Is this review positive or negative? Review: this is the best cast iron skillet you will ever buy", return_tensors="pt")
outputs = model.generate(inputs)
print(tokenizer.decode(outputs[0]))
# Out:
# Downloading:   0%|          | 0.00/632 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_20826/3219899785.py in <module>
#       2
#       3 tokenizer = AutoTokenizer.from_pretrained("bigscience/T0_3B")
# ----> 4 model = AutoModelForSeq2SeqLM.from_pretrained("bigscience/T0_3B")
#       5
#       6 test_sentence = "Is this review positive or negative? Review: this is the best cast iron skillet you will ever buy"
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     393         if type(config) in cls._model_mapping.keys():
#     394             model_class = _get_model_class(config, cls._model_mapping)
# --> 395             return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#     396         raise ValueError(
#     397             f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1137             try:
#    1138                 # Load from URL or cache if already cached
# -> 1139                 resolved_archive_file = cached_path(
#    1140                     archive_file,
#    1141                     cache_dir=cache_dir,
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1327     if is_remote_url(url_or_filename):
#    1328         # URL, so get it from the cache (downloading if necessary)
# -> 1329         output_path = get_from_cache(
#    1330             url_or_filename,
#    1331             cache_dir=cache_dir,
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1590             logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
#    1591
# -> 1592             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1593
#    1594         logger.info(f"storing {url} in cache at {cache_path}")
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1437     if resume_size > 0:
#    1438         headers["Range"] = f"bytes={resume_size}-"
# -> 1439     r = requests.get(url, stream=True, proxies=proxies, headers=headers)
#    1440     r.raise_for_status()
#    1441     content_length = r.headers.get("Content-Length")
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/PJ/Documents/NLP_PJ/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/PJ/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/PJ/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/PJ/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/PJ/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/PJ/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/PJ/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
